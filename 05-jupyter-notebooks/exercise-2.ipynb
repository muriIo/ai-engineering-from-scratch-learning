# %%
import pandas as pd
import matplotlib.pyplot as plt

print ("--- Sales / Revenue Analysis ---")
data = pd.read_csv("sales.csv")
df = pd.DataFrame(data)

print(df.to_string(index=False))
# Out:
# --- Sales / Revenue Analysis ---
#       date product  sales  revenue
# 2024-01-01  Apples    120    240.0
# 2024-01-02 Bananas     85    127.5
# 2024-01-03  Apples     95    190.0
# 2024-01-04 Oranges    110    220.0
# 2024-01-05 Bananas    130    195.0
# 2024-01-06 Oranges     75    150.0
# 2024-01-07  Apples    140    280.0
# 2024-01-08 Bananas     90    135.0
# 2024-01-09 Oranges    105    210.0
# 2024-01-10  Apples    115    230.0
