# %%
import numpy as np

# %timeit np.random.randn(10000)

# %%
import random


def generate():
    values = []
    for x in range(10000):
        values.append(random.randrange(0, 10000))

# %timeit generate()
